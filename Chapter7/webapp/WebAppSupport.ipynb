# %%
import swimclub

swimclub.produce_bar_chart('Abi-10-50m-Back.txt')
# Out:
# 'charts/Abi-10-50m-Back.html'

# %%
filename = 'Abi-10-50m-Back.txt'

filename.removesuffix('.txt').split('-', 2)[-1]
# Out:
# 'Abi'
